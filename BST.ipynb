# %% [markdown]
# <a href="https://colab.research.google.com/github/sangramshitole07/ADS-AIML2026/blob/main/BST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:

    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None

# %%
class BST:

    def __init__(self):
        self.root = None
